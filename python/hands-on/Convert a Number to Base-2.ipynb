# %% [markdown]
# ![Screen%20Shot%202021-07-31%20at%2019.58.57.png](attachment:Screen%20Shot%202021-07-31%20at%2019.58.57.png)

# %%
def binary(decimal):
    result = ""
    while decimal >=1:
        result += str(int(decimal%2))
       
        decimal -= (decimal/2)
       
    return result[::-1]
print(binary(15))
# Out:
# 1111

# %%
def binary(decimal):
    return bin(decimal).replace("0b","")
print(binary(15))
# Out:
# 1111
