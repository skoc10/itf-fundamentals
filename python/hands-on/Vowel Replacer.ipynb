# %% [markdown]
# ![Screen%20Shot%202021-07-27%20at%2014.54.31.png](attachment:Screen%20Shot%202021-07-27%20at%2014.54.31.png)

# %%
def replace_vowels(s, char):
    s1 = ''
    for i in s:
        if i in ['a', 'e', 'i', 'o', 'u']:
            s1+=char
        else:
            s1+=i               
    return s1

# %%
replace_vowels("shakespeare", "*")
# Out:
# 'sh*k*sp**r*'

# %%
replace_vowels("minnie mouse", "?")
# Out:
# 'm?nn?? m??s?'
